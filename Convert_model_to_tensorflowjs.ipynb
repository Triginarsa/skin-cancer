# %% [markdown]
# <a href="https://colab.research.google.com/github/Triginarsa/skin-cancer/blob/convert-to-tfjs/Convert_model_to_tensorflowjs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %%
pip install tensorflowjs
# Out:
# ...
#      |████████████████████████████████| 61kB 2.4MB/s
# ...
#      |████████████████████████████████| 92kB 5.5MB/s
# ...
#      |████████████████████████████████| 144.4MB 78kB/s
# ...
#      |████████████████████████████████| 256kB 41.5MB/s
# ...
#      |████████████████████████████████| 921kB 45.1MB/s
# ...
#   Created wheel for PyInquirer: filename=PyInquirer-1.0.3-cp36-none-any.whl size=32851 sha256=194ff866385e6ff60f81ca358fd8fb320849890b7c31300611b5212ee1da001a
#   Stored in directory: /root/.cache/pip/wheels/52/6c/b1/3e4b0e8daf42a92883c7641c0ea8ffb62e0490ebed2faa55ad
# Successfully built PyInquirer
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ...
#   Found existing installation: prompt-toolkit 1.0.18
#     Uninstalling prompt-toolkit-1.0.18:
#       Successfully uninstalled prompt-toolkit-1.0.18
#   Found existing installation: Pygments 2.1.3
#     Uninstalling Pygments-2.1.3:
#       Successfully uninstalled Pygments-2.1.3
# ...

# %%
# !tensorflowjs_converter --version
# Out:
# tensorflowjs 2.0.1
#
# Dependency versions:
#   keras 2.3.0-tf
#   tensorflow 2.2.0

# %%
model = tf.keras.models.load_model('/content/drive/My Drive/skin-cancer/experimen_4_model.h5',compile=False)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Conv1_pad (ZeroPadding2D)       (None, 225, 225, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 112, 112, 32) 864         Conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 112, 112, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 112, 112, 32) 0           bn_Conv1[0][0]
# ...

# %%
# !tensorflowjs_converter --input_format=keras --output_format=tfjs_layers_model /content/experimen_4_model.h5 /content/sample_data/

# !ls -ahl /content/sample_data
# Out:
# total 63M
# drwxr-xr-x 1 root root 4.0K Jun 21 15:26 .
# drwxr-xr-x 1 root root 4.0K Jun 21 13:54 ..
# -rwxr-xr-x 1 root root 1.7K Jan  1  2000 anscombe.json
# -rw-r--r-- 1 root root 295K Jun 17 16:18 california_housing_test.csv
# -rw-r--r-- 1 root root 1.7M Jun 17 16:18 california_housing_train.csv
# -rw-r--r-- 1 root root 4.0M Jun 21 15:26 group1-shard1of3.bin
# -rw-r--r-- 1 root root 4.0M Jun 21 15:26 group1-shard2of3.bin
# -rw-r--r-- 1 root root 664K Jun 21 15:26 group1-shard3of3.bin
# -rw-r--r-- 1 root root  18M Jun 17 16:18 mnist_test.csv
# -rw-r--r-- 1 root root  35M Jun 17 16:18 mnist_train_small.csv
# -rw-r--r-- 1 root root 100K Jun 21 15:26 model.json
# -rwxr-xr-x 1 root root  930 Jan  1  2000 README.md
